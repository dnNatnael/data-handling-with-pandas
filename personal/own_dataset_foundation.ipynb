# %% [markdown]
# ## Create Your Own Dataset (Foundation)
#
# **Task:** Build a DataFrame from a Dictionary
# - 5 columns (features)
# - 15 rows
# - Custom index

# %%
import pandas as pd

# Create dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Helen", "Ian", "Jane",
             "Kevin", "Laura", "Mike", "Nina", "Oscar"],
    "Age": [25, 30, 22, 35, 28, 40, 27, 32, 29, 24, 31, 26, 38, 23, 34],
    "Salary": [50000, 60000, 45000, 80000, 52000, 90000, 48000, 62000, 58000, 51000,
               61000, 47000, 85000, 46000, 70000],
    "Department": ["HR", "IT", "IT", "Finance", "HR", "Finance", "IT", "HR", "IT", "HR",
                   "Finance", "IT", "Finance", "HR", "IT"],
    "Experience": [2, 5, 1, 10, 3, 12, 2, 6, 4, 2, 7, 3, 11, 1, 8]
}

# Custom index
index_labels = [f"EMP_{i}" for i in range(1, 16)]

# Create DataFrame
df_custom = pd.DataFrame(data, index=index_labels)

print(df_custom)
# Out:
#            Name  Age  Salary Department  Experience
# EMP_1     Alice   25   50000         HR           2
# EMP_2       Bob   30   60000         IT           5
# EMP_3   Charlie   22   45000         IT           1
# EMP_4     David   35   80000    Finance          10
# EMP_5       Eva   28   52000         HR           3
# EMP_6     Frank   40   90000    Finance          12
# EMP_7     Grace   27   48000         IT           2
# EMP_8     Helen   32   62000         HR           6
# EMP_9       Ian   29   58000         IT           4
# EMP_10     Jane   24   51000         HR           2
# EMP_11    Kevin   31   61000    Finance           7
# EMP_12    Laura   26   47000         IT           3
# EMP_13     Mike   38   85000    Finance          11
# EMP_14     Nina   23   46000         HR           1
# EMP_15    Oscar   34   70000         IT           8
